# %%
import numpy as np 
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/dartfs/rc/nosnapshots/V/VaickusL-nb/EDIT_Students/users/alos/colon_work/adata/"

# %%
matrix = np.load(path)

# %%
matrix[0]
# Out:
# 5250.4766

# %%
plt.figure(figsize=(10, 6))
plt.hist(matrix[0], bins=200)
plt.title("Gene Expression Per Gene in 1 Spot")
plt.xlabel('Number of Genes')
plt.ylabel('Number of Spots')
plt.show()

# %%
matrix.shape
# Out:
# (7416, 17796)
